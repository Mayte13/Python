# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/jamc88/Analisis-datos-atmosfericos/refs/heads/main/datos/rama_2023_05.csv", parse_dates= True, index_col=0)

#es para llamar ya de una vez la fecha

# %%
df
# Out:
#                   CO         NO        NO2        NOX         O3        PM10  \
# fecha
# 2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150  105.573684
# 2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366   36.687845
# 2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486   29.269022
# 2015-01-04  0.726940  24.606272  19.560976  44.165505  17.329032   39.961538
# 2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588   31.855643
# ...              ...        ...        ...        ...        ...         ...
# 2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645   36.774011
# 2023-05-28  0.286826   3.458886  16.349241  20.230769  36.913761   28.580000
# 2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068   30.241486
# 2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971   35.859532
# 2023-05-31  0.340404   5.353066  19.372583  25.710359  47.860972   42.203390
#
#                  PM25        SO2
# ...

# %%
df.skew()

# encuentra el coeficiente de asimetría de Fisher
# Out:
# CO      1.063310
# NO      1.265967
# NO2     0.773803
# NOX     0.977845
# O3      0.374217
# PM10    0.559250
# PM25    1.302965
# SO2     2.802113
# dtype: float64

# %%
sns.histplot(df['CO'], bins=30, color='purple')
plt.show()

# esto sirve para ver que tanto se parece a una normal

# %%
sns.histplot(df['SO2'], bins=40, color='aqua')
plt.show()

# %%
sns.histplot(df['PM25'], bins=100, color='fuchsia')
plt.show()

# %%
from scipy.stats import shapiro
# esta patequeria tienes varias pruebas estadisticas
# Realiza la prueba de S-W a los contaminantes.

# %%
estadistico, p_value=shapiro(df['CO'])
print('valor del estadistico=%.3f, p_value=%.3f'% (estadistico, p_value))
# Out:
# valor del estadistico=0.938, p_value=0.000

# %%
estadistico, p_value=shapiro(df['PM10'])
print('valor del estadistico=%.3f, p_value=%.3f'% (estadistico, p_value))
# Out:
# valor del estadistico=0.978, p_value=0.000

# %%
estadistico, p_value=shapiro(df['PM25'])
print('valor del estadistico=%.3f, p_value=%.3f'% (estadistico, p_value))
# Out:
# valor del estadistico=0.936, p_value=0.000

# %% [markdown]
# ***Correlación***

# %%
A=[35,23,47,17,10,43,9,6,28]
B=[30,33,45,23,8,49,12,4,31]

# %%
A=sorted(A, reverse=True)
B=sorted(B, reverse=True)

# %%
print(A)
print(B)
# Out:
# [47, 43, 35, 28, 23, 17, 10, 9, 6]
# [49, 45, 33, 31, 30, 23, 12, 8, 4]

# %% [markdown]
# Encuentre la correlación entre los contaminantes e ilustra esto mediante un grafico

# %%
correlation_matrix = df.corr('spearman')
# este es muy efectivo

# %%
correlation_matrix
# Out:
#             CO        NO       NO2       NOX        O3      PM10      PM25  \
# CO    1.000000  0.792279  0.844874  0.854311 -0.057146  0.525460  0.540627
# NO    0.792279  1.000000  0.801656  0.959736 -0.213371  0.539598  0.402232
# NO2   0.844874  0.801656  1.000000  0.932275  0.064124  0.695687  0.693741
# NOX   0.854311  0.959736  0.932275  1.000000 -0.088925  0.646696  0.560590
# O3   -0.057146 -0.213371  0.064124 -0.088925  1.000000  0.408806  0.462961
# PM10  0.525460  0.539598  0.695687  0.646696  0.408806  1.000000  0.858762
# PM25  0.540627  0.402232  0.693741  0.560590  0.462961  0.858762  1.000000
# SO2   0.377411  0.328189  0.476221  0.411711  0.093813  0.548739  0.547311
#
#            SO2
# CO    0.377411
# NO    0.328189
# NO2   0.476221
# NOX   0.411711
# O3    0.093813
# PM10  0.548739
# PM25  0.547311
# SO2   1.000000

# %%
plt.figure(figsize=(8,6),dpi=100)
sns.heatmap(correlation_matrix, annot = True, cmap='coolwarm', vmin=-1,vmax=1,center=0)
# Out:
# <Axes: >

# %%
pip install pingouin
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 5.3 MB/s eta 0:00:00
# ...

# %%
import pingouin as pg

# %% [markdown]
#  Obtenga un Dataframe con los contaminantes que tengan una correlación alta en orden descendente. Y los diagramas de dispersión entre todos los contaminantes.

# %%
corr=pg.pairwise_corr(df, method='spearman')

# %%
corr
#toma los valores de quienes se correlacionan mas
# Out:
#        X     Y    method alternative     n         r           CI95%  \
# 0     CO    NO  spearman   two-sided  3073  0.792279    [0.78, 0.81]
# 1     CO   NO2  spearman   two-sided  3073  0.844874    [0.83, 0.85]
# 2     CO   NOX  spearman   two-sided  3073  0.854311    [0.84, 0.86]
# 3     CO    O3  spearman   two-sided  3073 -0.057146  [-0.09, -0.02]
# 4     CO  PM10  spearman   two-sided  3073  0.525460     [0.5, 0.55]
# 5     CO  PM25  spearman   two-sided  3073  0.540627    [0.52, 0.57]
# 6     CO   SO2  spearman   two-sided  3073  0.377411    [0.35, 0.41]
# 7     NO   NO2  spearman   two-sided  3073  0.801656    [0.79, 0.81]
# 8     NO   NOX  spearman   two-sided  3073  0.959736    [0.96, 0.96]
# 9     NO    O3  spearman   two-sided  3073 -0.213371  [-0.25, -0.18]
# 10    NO  PM10  spearman   two-sided  3073  0.539598    [0.51, 0.56]
# 11    NO  PM25  spearman   two-sided  3073  0.402232    [0.37, 0.43]
# 12    NO   SO2  spearman   two-sided  3073  0.328189     [0.3, 0.36]
# ...

# %%
corr.sort_values(by='r', ascending=False)[['X','Y','r']]
#le dicimos sobre que columna  va a realizar la correlacion
# nos va dar quien se correlacioinan mas
# Out:
#        X     Y         r
# 8     NO   NOX  0.959736
# 13   NO2   NOX  0.932275
# 25  PM10  PM25  0.858762
# 2     CO   NOX  0.854311
# 1     CO   NO2  0.844874
# 7     NO   NO2  0.801656
# 0     CO    NO  0.792279
# 15   NO2  PM10  0.695687
# 16   NO2  PM25  0.693741
# 19   NOX  PM10  0.646696
# 20   NOX  PM25  0.560590
# 26  PM10   SO2  0.548739
# 27  PM25   SO2  0.547311
# 5     CO  PM25  0.540627
# 10    NO  PM10  0.539598
# 4     CO  PM10  0.525460
# 17   NO2   SO2  0.476221
# 23    O3  PM25  0.462961
# 21   NOX   SO2  0.411711
# 22    O3  PM10  0.408806
# 11    NO  PM25  0.402232
# 6     CO   SO2  0.377411
# 12    NO   SO2  0.328189
# 24    O3   SO2  0.093813
# 14   NO2    O3  0.064124
# 3     CO    O3 -0.057146
# 18   NOX    O3 -0.088925
# 9     NO    O3 -0.213371

# %%
c=corr.sort_values(by='r', ascending=False)[['X','Y','r']]
c=c[(c['r']>0.5) | (c['r']<-0.5)]
#este comando es para ver que variables son las que se correlacionan mas y cuales no tienen correlacion

# %%
c
# Out:
#        X     Y         r
# 8     NO   NOX  0.959736
# 13   NO2   NOX  0.932275
# 25  PM10  PM25  0.858762
# 2     CO   NOX  0.854311
# 1     CO   NO2  0.844874
# 7     NO   NO2  0.801656
# 0     CO    NO  0.792279
# 15   NO2  PM10  0.695687
# 16   NO2  PM25  0.693741
# 19   NOX  PM10  0.646696
# 20   NOX  PM25  0.560590
# 26  PM10   SO2  0.548739
# 27  PM25   SO2  0.547311
# 5     CO  PM25  0.540627
# 10    NO  PM10  0.539598
# 4     CO  PM10  0.525460

# %% [markdown]
# podemos ver que NO con NOX son las que se correlacionan mas

# %% [markdown]
# ***Factores meteorológicos***

# %% [markdown]
# ¿Existe una correlación entre los contaminantes y los factores meteorológicos?

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/jamc88/Analisis-datos-atmosfericos/refs/heads/main/datos/redmet_2023_05.csv', parse_dates= True, index_col=0)

# %%
df2
# Out:
#                    RH        TMP         WDR       WSP
# fecha
# 2015-01-01  60.565476  13.385714  156.723039  1.933333
# 2015-01-02  52.452381  13.567262  176.710784  2.559804
# 2015-01-03  55.763636  13.893333  190.830846  2.136318
# 2015-01-04  62.776786  12.536012  196.306373  2.592647
# 2015-01-05  70.271845   9.070227  266.889764  2.963517
# ...               ...        ...         ...       ...
# 2023-05-27  51.899130  19.453565  190.198664  2.187646
# 2023-05-28  59.949565  17.375826  183.542571  2.092154
# 2023-05-29  58.837743  17.039153  169.527919  1.952284
# 2023-05-30  50.145719  18.684699  184.998255  1.978709
# 2023-05-31  50.353261  20.089130  172.697917  1.962153
#
# [3073 rows x 4 columns]

# %%
estadistico, p_value = shapiro(df2['RH'])
print('valor del estadistico=%.3f, p_value=%.3f'% (estadistico, p_value))
# Out:
# valor del estadistico=0.985, p_value=0.000

# %%
estadistico, p_value = shapiro(df2['TMP'])
print('valor del estadistico=%.3f, p_value=%.3f'% (estadistico, p_value))
# Out:
# valor del estadistico=0.992, p_value=0.000

# %%
estadistico, p_value = shapiro(df2['WDR'])
print('valor del estadistico=%.3f, p_value=%.3f'% (estadistico, p_value))
# Out:
# valor del estadistico=0.940, p_value=0.000

# %%
estadistico, p_value = shapiro(df2['WSP'])
print('valor del estadistico=%.3f, p_value=%.3f'% (estadistico, p_value))
# Out:
# valor del estadistico=0.921, p_value=0.000

# %%
cn=pd.concat([df,df2], axis=1)

# %%
cn
# Out:
#                   CO         NO        NO2        NOX         O3        PM10  \
# fecha
# 2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150  105.573684
# 2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366   36.687845
# 2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486   29.269022
# 2015-01-04  0.726940  24.606272  19.560976  44.165505  17.329032   39.961538
# 2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588   31.855643
# ...              ...        ...        ...        ...        ...         ...
# 2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645   36.774011
# 2023-05-28  0.286826   3.458886  16.349241  20.230769  36.913761   28.580000
# 2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068   30.241486
# 2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971   35.859532
# 2023-05-31  0.340404   5.353066  19.372583  25.710359  47.860972   42.203390
#
# ...

# %%
cor_matrix=cn.corr('spearman')
plt.figure(figsize=(8,6),dpi=200)
sns.heatmap(cor_matrix, annot = True, cmap='coolwarm', vmin=-1,vmax=1,center=0)
# Out:
# <Axes: >

# %%
corr=pg.pairwise_corr(cn, method='spearman')
c=corr.sort_values(by='r', ascending=False)[['X','Y','r']]
c=c[(c['r']>0.5) | (c['r']<-0.5)]
c
# Out:
#        X     Y         r
# 12    NO   NOX  0.959736
# 21   NO2   NOX  0.932275
# 45  PM10  PM25  0.858762
# 2     CO   NOX  0.854311
# 1     CO   NO2  0.844874
# 11    NO   NO2  0.801656
# 0     CO    NO  0.792279
# 23   NO2  PM10  0.695687
# 24   NO2  PM25  0.693741
# 31   NOX  PM10  0.646696
# 42    O3   TMP  0.567159
# 32   NOX  PM25  0.560590
# 46  PM10   SO2  0.548739
# 51  PM25   SO2  0.547311
# 5     CO  PM25  0.540627
# 14    NO  PM10  0.539598
# 4     CO  PM10  0.525460
# 10    CO   WSP -0.511768
# 37   NOX   WSP -0.535938
# 29   NO2   WSP -0.607549
# 47  PM10    RH -0.641513

# %%
sns.scatterplot(x='RH', y='PM10', data=cn)
# SI AUMENTA LA HUMEDAD disminuye el PM10
# Out:
# <Axes: xlabel='RH', ylabel='PM10'>

# %%
sns.scatterplot(x='NO', y='NOX', data=cn)
# Out:
# <Axes: xlabel='NO', ylabel='NOX'>

# %%
sns.pairplot(cn)
#en la diagonal principal se ve la distribucion de cada uno de los contaminantes
# Out:
# Output hidden; open in https://colab.research.google.com to view.
