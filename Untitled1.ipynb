# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jamc88/Analisis-datos-atmosfericos/refs/heads/main/datos/rama_2023_05.csv")

# %%
df.head(10)

#  este comando sirve para llamar las primeras filas de los contaminantes
# Out:
#         fecha        CO         NO        NO2        NOX         O3  \
# 0  2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150
# 1  2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366
# 2  2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486
# 3  2015-01-04  0.726940  24.606272  19.560976  44.165505  17.329032
# 4  2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588
# 5  2015-01-06  0.748952  27.977346  23.242718  51.213592  12.902256
# 6  2015-01-07  0.443254  11.297114  16.259762  27.594228  17.055130
# 7  2015-01-08  0.533528  10.527586  21.625862  32.155172  19.150555
# 8  2015-01-09  1.094574  41.795181  32.526678  74.283993  19.482813
# 9  2015-01-10  0.770722  23.455717  27.468599  50.919485  22.689552
#
#          PM10       PM25        SO2
# 0  105.573684  78.953405  11.554723
# 1   36.687845  15.449438   1.895052
# 2   29.269022  12.915129   1.436937
# 3   39.961538  16.838284   1.809061
# ...

# %%
df.tail()

#sirve para llamar los ultimos datos de los contaminantes ( se nos dan en filas)
# Out:
#            fecha        CO         NO        NO2        NOX         O3  \
# 3068  2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645
# 3069  2023-05-28  0.286826   3.458886  16.349241  20.230769  36.913761
# 3070  2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068
# 3071  2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971
# 3072  2023-05-31  0.340404   5.353066  19.372583  25.710359  47.860972
#
#            PM10       PM25       SO2
# 3068  36.774011  21.170139  2.735683
# 3069  28.580000  18.454861  2.331658
# 3070  30.241486  16.692857  1.071588
# 3071  35.859532  20.888525  1.181818
# 3072  42.203390  24.787097  1.402083

# %%
df.info()

# muestra los datos que tengo en la tabla
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   3073 non-null   object
#  1   CO      3073 non-null   float64
#  2   NO      3073 non-null   float64
#  3   NO2     3073 non-null   float64
#  4   NOX     3073 non-null   float64
#  5   O3      3073 non-null   float64
#  6   PM10    3073 non-null   float64
#  7   PM25    3073 non-null   float64
#  8   SO2     3073 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 216.2+ KB

# %%
df['CO'].mean()
# Out:
# 0.4819260524259833

# %%
df['NOX'].median()
# Out:
# 35.880222841225624

# %%
df['PM25'].sum()
# Out:
# 65539.01256769303

# %%
df['O3'].quantile([.25, .50, .75])
# Out:
# 0.25    23.923077
# 0.50    29.838384
# 0.75    36.216012
# Name: O3, dtype: float64

# %%
plt.boxplot(df['NO2'],vert = False)
plt.show()

#aqui se muestra la grafica de caja
#vert = False te da la grafica en forma horizontal

# %%
plt.boxplot(df['PM10'],vert = False)
plt.show()

# %%
plt.boxplot(df['PM25'],vert = False)
plt.show()

# %%
plt.boxplot(df[['O3','NO','PM25']],vert = False)
plt.show()

# %%
import seaborn as sns

#PAQUETERIA

# %%
sns.boxplot(data=df,orient='h')
# Out:
# <Axes: >

# %%
df['NOX'].quantile([.25])
# Out:
# 0.25    26.938073
# Name: NOX, dtype: float64

# %%
df['NOX'].quantile([.75])
# Out:
# 0.75    46.739777
# Name: NOX, dtype: float64

# %%
IQR=46.739777-26.938073

# %%
limitesuperior=46.739777+1.5*IQR

# %%
limitesuperior
# Out:
# 76.44233299999999

# %%
tab1=df[df['NOX']>limitesuperior]

#Tabla que muestra los datos fuera del limite superior de NOX

# %%
tab1
# Out:
#            fecha        CO         NO        NO2         NOX         O3  \
# 300   2015-10-28  1.372311  45.855556  37.611111   83.483333   9.061873
# 333   2015-11-30  1.206702  40.646893  46.649718   87.296610  31.528761
# 334   2015-12-01  1.346911  48.621687  49.959036   98.563855  32.173285
# 335   2015-12-02  1.170023  41.613744  41.537915   83.168246  34.519856
# 342   2015-12-09  1.225478  44.491765  40.176471   84.654118  20.076106
# 343   2015-12-10  1.239224  40.892086  45.414868   86.292566  28.603232
# 344   2015-12-11  1.312555  46.114486  45.605140   91.745327  27.717277
# 349   2015-12-16  1.026555  48.171021  30.389549   78.567696  21.050000
# 354   2015-12-21  1.213817  36.889412  44.056471   80.957647  25.956124
# 356   2015-12-23  1.496288  59.714617  42.396752  102.088167   8.738182
# 357   2015-12-24  1.482022  52.140957  41.811170   93.936170  28.785417
# 376   2016-01-12  1.146875  49.837054  38.783482   88.602679  13.936620
# ...

# %%
tab1['NOX'].count()

#datos atípicos tienen los óxidos de nitrógeno
# Out:
# 50

# %%
tab1['fecha']
#en estas fechas se registraron dados atipicos del contaminante NOX
# Out:
# 300     2015-10-28
# 333     2015-11-30
# 334     2015-12-01
# 335     2015-12-02
# 342     2015-12-09
# 343     2015-12-10
# 344     2015-12-11
# 349     2015-12-16
# 354     2015-12-21
# 356     2015-12-23
# 357     2015-12-24
# 376     2016-01-12
# 380     2016-01-16
# 381     2016-01-17
# 382     2016-01-18
# 385     2016-01-21
# 389     2016-01-25
# 393     2016-01-29
# 394     2016-01-30
# 398     2016-02-03
# 410     2016-02-15
# 686     2016-11-17
# 735     2017-01-05
# 736     2017-01-06
# 741     2017-01-11
# 753     2017-01-23
# 756     2017-01-26
# 1058    2017-11-24
# 1068    2017-12-04
# 1069    2017-12-05
# 1070    2017-12-06
# 1075    2017-12-11
# 1076    2017-12-12
# 1077    2017-12-13
# 1078    2017-12-14
# 1079    2017-12-15
# 1083    2017-12-19
# 1086    2017-12-22
# 1105    2018-01-10
# 1106    2018-01-11
# 1127    2018-02-01
# 1413    2018-11-14
# 1422    2018-11-23
# 1446    2018-12-17
# 1450    2018-12-21
# 1451    2018-12-22
# 1831    2020-01-06
# ...

# %%
fig, ax = plt.subplots()
ax.plot(df['NOX']);

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3073, step=1)

# %%
tab1.index
# Out:
# Index([ 300,  333,  334,  335,  342,  343,  344,  349,  354,  356,  357,  376,
#         380,  381,  382,  385,  389,  393,  394,  398,  410,  686,  735,  736,
#         741,  753,  756, 1058, 1068, 1069, 1070, 1075, 1076, 1077, 1078, 1079,
#        1083, 1086, 1105, 1106, 1127, 1413, 1422, 1446, 1450, 1451, 1831, 2547,
#        2548, 2549],
#       dtype='int64')

# %%
df['fecha'] = pd.to_datetime(df['fecha'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fecha   3073 non-null   datetime64[ns]
#  1   CO      3073 non-null   float64
#  2   NO      3073 non-null   float64
#  3   NO2     3073 non-null   float64
#  4   NOX     3073 non-null   float64
#  5   O3      3073 non-null   float64
#  6   PM10    3073 non-null   float64
#  7   PM25    3073 non-null   float64
#  8   SO2     3073 non-null   float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 216.2 KB

# %%
df=df.set_index('fecha')

# %%
df
# Out:
#                   CO         NO        NO2        NOX         O3        PM10  \
# fecha
# 2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150  105.573684
# 2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366   36.687845
# 2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486   29.269022
# 2015-01-04  0.726940  24.606272  19.560976  44.165505  17.329032   39.961538
# 2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588   31.855643
# ...              ...        ...        ...        ...        ...         ...
# 2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645   36.774011
# 2023-05-28  0.286826   3.458886  16.349241  20.230769  36.913761   28.580000
# 2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068   30.241486
# 2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971   35.859532
# 2023-05-31  0.340404   5.353066  19.372583  25.710359  47.860972   42.203390
#
#                  PM25        SO2
# ...

# %%
fig, ax = plt.subplots()
ax.plot(df['NOX']);

# %%
fig, ax = plt.subplots()
ax.plot(df['O3']);

# %%
fig, ax = plt.subplots()
ax.plot(df['PM10']);

# %%
fig, ax = plt.subplots()
ax.plot(df['PM25']);

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=200)
ax.plot(df['NOX'], color='pink',lw=0.6);
ax.tick_params(labelsize=10)
ax.set_xlabel('Tiempo', fontdict = {'fontsize':14 })
ax.set_ylabel('CO ($\mu$g/$m^3$)', fontdict = {'fontsize':14 });
ax.grid(True)

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=200)
ax.plot(df['PM10'], color='purple',lw=0.6);
ax.tick_params(labelsize=10)
ax.set_xlabel('Tiempo', fontdict = {'fontsize':14 })
ax.set_ylabel('CO ($\mu$g/$m^3$)', fontdict = {'fontsize':14 });
ax.grid(True)

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=200)
ax.plot(df['NOX'], color='green',lw=0.6);
ax.tick_params(labelsize=10)
ax.set_xlabel('Tiempo', fontdict = {'fontsize':14 })
ax.set_ylabel('CO ($\mu$g/$m^3$)', fontdict = {'fontsize':14 });
ax.grid(True)

# %%
df['PM25']['2022-01':'2022-12'][df['PM25']>25]
# Out:
# fecha
# 2022-01-01    58.414835
# 2022-01-03    28.670588
# 2022-01-04    32.527687
# 2022-01-05    27.703125
# 2022-01-06    25.186747
#                 ...
# 2022-12-20    29.639394
# 2022-12-22    27.008523
# 2022-12-23    25.591549
# 2022-12-24    26.856397
# 2022-12-25    37.955224
# Name: PM25, Length: 75, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(10,5),dpi=100)
ax.plot(df['PM25']['2022-01-01':'2022-12-31'], color='brown',lw=0.6);
ax.tick_params(labelsize=14)
ax.set_xlabel('Tiempo', fontdict = {'fontsize':14 })
ax.set_ylabel('PM25 ($\mu$g/$m^3$)', fontdict = {'fontsize':14 });
ax.axhline(25,color='red',lw=2,linestyle='--')
plt.show()

# %%
df.skew()
 #muestra el numero de asimetría
# Out:
# CO      1.063310
# NO      1.265967
# NO2     0.773803
# NOX     0.977845
# O3      0.374217
# PM10    0.559250
# PM25    1.302965
# SO2     2.802113
# dtype: float64

# %%
sns.histplot(df['CO'], bins=30, color='pink')
plt.show()
#la grafica muestra como se forma la grafica de asimetria positiva

# %%
df.kurt()

# aqui todos los datos muestran que la  curtosis (Kurtosis) es mayor a cero entonces estamos hablando de una distribución  leptocúrtica
# Out:
# CO       1.683262
# NO       2.462188
# NO2      1.428723
# NOX      1.776258
# O3       0.038129
# PM10     0.314006
# PM25     5.184911
# SO2     10.735611
# dtype: float64
